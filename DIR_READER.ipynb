# %%
from passlib.context import CryptContext

pwd_context = CryptContext(schemes=["argon2"], deprecated="auto")
def verify_password(plain_password, hashed_password):
    return pwd_context.verify(plain_password, hashed_password)

def get_password_hash(password):
    return pwd_context.hash(password)

# %%
hashed = "$argon2id$v=19$m=65536,t=3,p=4$jrGW0jqntPae09p7T8lZCw$PtVIpMmKqBeyisTnPJKun1N0ilnvl6m7qAT/BrY3JJo"

# %%
pw = "admin123"
verify_password(pw,  hashed)
# Out:
# False

# %%
# %cd C:\Users\phongnv37\fastapi-stud\
# Out:
# C:\Users\phongnv37\fastapi-stud
# c:\Users\phongnv37\fastapi-stud\.venv\lib\site-packages\IPython\core\magics\osm.py:417: UserWarning: This is now an optional IPython functionality, setting dhist requires you to install the `pickleshare` library.
#   self.shell.db['dhist'] = compress_dhist(dhist)[-100:]

# %%
import os
from pathlib import Path

def print_directory_tree(root_dir, indent="", exclude_hidden=True):
    """
    Print a directory tree structure starting from root_dir.
    
    Args:
        root_dir (str): The root directory to start from
        indent (str): Current indentation (used in recursion)
        exclude_hidden (bool): Whether to exclude hidden files/directories
    """
    root = Path(root_dir)
    
    # Get all items in the directory
    items = list(root.iterdir())
    items.sort(key=lambda x: (not x.is_dir(), x.name.lower()))
    
    # Count of items to process
    count = len(items)
    
    for i, item in enumerate(items):
        # Skip hidden files/directories if exclude_hidden is True
        if exclude_hidden and item.name.startswith('.'):
            continue
        
        # Check if this is the last item at this level
        is_last = i == count - 1
        
        # Choose the appropriate connector symbols
        connector = "└── " if is_last else "├── "
        
        # Print the current item
        print(f"{indent}{connector}{item.name}")
        
        # If it's a directory, recursively print its contents
        if item.is_dir():
            # Adjust indentation for the next level
            next_indent = indent + ("    " if is_last else "│   ")
            print_directory_tree(item, next_indent, exclude_hidden)

# Example usage
if __name__ == "__main__":
    import sys
    
    # Use command line argument if provided, otherwise use current directory
    directory = os.curdir
    
    print(f"Directory tree for: {os.path.abspath(directory)}")
    print_directory_tree(directory)
# Out:
# Directory tree for: C:\Users\phongnv37\fastapi-stud
# ├── __pycache__
# │   └── __init__.cpython-313.pyc
# ├── backend
# │   ├── __pycache__
# │   │   ├── __init__.cpython-313.pyc
# │   │   └── config.cpython-313.pyc
# │   ├── config
# │   │   ├── __pycache__
# │   │   │   └── settings.cpython-313.pyc
# │   │   └── settings.py
# │   ├── rag_sys
# │   │   ├── data
# │   │   │   ├── 10 YEARS OF ETHNOPHARMACOLOGY.PDF
# │   │   │   ├── 10 YEARS OF GASTROINTESTINAL .PDF
# │   │   │   ├── 10 YEARS OF INFLAMMATION .PDF
# │   │   │   ├── 10 YEARS OF NEUROPHARMACOLOGY.PDF
# │   │   │   └── Co-production of knowledge in action.pdf
# │   │   └── src
# │   │       ├── __pycache__
# │   │       │   ├── main.cpython-310.pyc
# │   │       │   └── main.cpython-313.pyc
# │   │       ├── adapter
# │   │       │   ├── embedder
# │   │       │   │   └── google_ai_embedder.py
# │   │       │   ├── llms
# │   │       │   │   ├── __pycache__
# │   │       │   │   │   ├── cerebras.cpython-310.pyc
# │   │       │   │   │   └── cerebras.cpython-313.pyc
# │   │       │   │   └── cerebras.py
# │   │       │   ├── persistence
# │   │       │   │   ├── __pycache__
# │   │       │   │   │   ├── logger.cpython-310.pyc
# │   │       │   │   │   ├── logger.cpython-313.pyc
# │   │       │   │   │   ├── vectorizer.cpython-310.pyc
# │   │       │   │   │   └── vectorizer.cpython-313.pyc
# │   │       │   │   ├── graph_log.txt
# │   │       │   │   ├── logger.py
# │   │       │   │   └── vectorizer.py
# │   │       │   └── tools
# │   │       │       ├── __pycache__
# │   │       │       │   ├── human_assistance.cpython-310.pyc
# │   │       │       │   ├── human_assistance.cpython-313.pyc
# │   │       │       │   ├── tavily_search.cpython-310.pyc
# │   │       │       │   └── tavily_search.cpython-313.pyc
# │   │       │       ├── human_assistance.py
# │   │       │       └── tavily_search.py
# │   │       ├── domain
# │   │       │   ├── entities
# │   │       │   │   └── message.py
# │   │       │   └── state.py
# │   │       ├── infrastructure
# │   │       │   ├── __pycache__
# │   │       │   │   ├── settings.cpython-310.pyc
# │   │       │   │   └── settings.cpython-313.pyc
# │   │       │   ├── settings.py
# │   │       │   └── visualizer.py
# │   │       ├── presentation
# │   │       │   ├── cli.py
# │   │       │   └── stream_handler.py
# │   │       ├── use_cases
# │   │       │   └── chat_flow.py
# │   │       ├── main.py
# │   │       ├── rag.py
# │   │       └── visualizer_app.py
# │   ├── src
# │   │   ├── __pycache__
# │   │   │   └── main.cpython-313.pyc
# │   │   ├── application
# │   │   │   ├── interfaces
# │   │   │   │   ├── __pycache__
# │   │   │   │   │   ├── __init__.cpython-313.pyc
# │   │   │   │   │   ├── author_repository.cpython-313.pyc
# │   │   │   │   │   ├── book_repository.cpython-313.pyc
# │   │   │   │   │   ├── borrowing_repository.cpython-313.pyc
# │   │   │   │   │   └── user_repository.cpython-313.pyc
# │   │   │   │   ├── __init__.py
# │   │   │   │   ├── author_repository.py
# │   │   │   │   ├── book_repository.py
# │   │   │   │   ├── borrowing_repository.py
# │   │   │   │   └── user_repository.py
# │   │   │   └── use_cases
# │   │   │       ├── author_ops
# │   │   │       │   ├── __pycache__
# │   │   │       │   │   ├── __init__.cpython-313.pyc
# │   │   │       │   │   ├── create_author.cpython-313.pyc
# │   │   │       │   │   ├── delete_author.cpython-313.pyc
# │   │   │       │   │   ├── get_author.cpython-313.pyc
# │   │   │       │   │   ├── search_author.cpython-313.pyc
# │   │   │       │   │   └── update_author.cpython-313.pyc
# │   │   │       │   ├── __init__.py
# │   │   │       │   ├── create_author.py
# │   │   │       │   ├── delete_author.py
# │   │   │       │   ├── get_author.py
# │   │   │       │   ├── search_author.py
# │   │   │       │   └── update_author.py
# │   │   │       ├── book_ops
# │   │   │       │   ├── __pycache__
# │   │   │       │   │   ├── __init__.cpython-313.pyc
# │   │   │       │   │   ├── create_book.cpython-313.pyc
# │   │   │       │   │   ├── delete_book.cpython-313.pyc
# │   │   │       │   │   ├── get_book.cpython-313.pyc
# │   │   │       │   │   ├── search_book.cpython-313.pyc
# │   │   │       │   │   └── update_book.cpython-313.pyc
# │   │   │       │   ├── __init__.py
# │   │   │       │   ├── create_book.py
# │   │   │       │   ├── delete_book.py
# │   │   │       │   ├── get_book.py
# │   │   │       │   ├── search_book.py
# │   │   │       │   └── update_book.py
# │   │   │       ├── borrowing_ops
# │   │   │       │   ├── __pycache__
# │   │   │       │   │   ├── __init__.cpython-313.pyc
# │   │   │       │   │   ├── create_borrowing.cpython-313.pyc
# │   │   │       │   │   ├── delete_borrowing.cpython-313.pyc
# │   │   │       │   │   ├── get_borrowing.cpython-313.pyc
# │   │   │       │   │   └── update_borrowing.cpython-313.pyc
# │   │   │       │   ├── __init__.py
# │   │   │       │   ├── create_borrowing.py
# │   │   │       │   ├── delete_borrowing.py
# │   │   │       │   ├── get_borrowing.py
# │   │   │       │   └── update_borrowing.py
# │   │   │       └── user_ops
# │   │   │           ├── __pycache__
# │   │   │           │   ├── __init__.cpython-313.pyc
# │   │   │           │   ├── create_user.cpython-313.pyc
# │   │   │           │   ├── delete_user.cpython-313.pyc
# │   │   │           │   ├── get_user.cpython-313.pyc
# │   │   │           │   ├── search_user.cpython-313.pyc
# │   │   │           │   └── update_user.cpython-313.pyc
# │   │   │           ├── __init__.py
# │   │   │           ├── create_user.py
# │   │   │           ├── delete_user.py
# │   │   │           ├── get_user.py
# │   │   │           ├── search_user.py
# │   │   │           └── update_user.py
# │   │   ├── domain
# │   │   │   ├── entities
# │   │   │   │   ├── __pycache__
# │   │   │   │   │   ├── author_ent.cpython-313.pyc
# │   │   │   │   │   ├── book_ent.cpython-313.pyc
# │   │   │   │   │   ├── borrowing_ent.cpython-313.pyc
# │   │   │   │   │   ├── models.cpython-313.pyc
# │   │   │   │   │   └── user_ent.cpython-313.pyc
# │   │   │   │   └── models.py
# │   │   │   └── services
# │   │   │       ├── __pycache__
# │   │   │       │   └── utils.cpython-313.pyc
# │   │   │       └── utils.py
# │   │   ├── infrastructure
# │   │   │   ├── persistence
# │   │   │   │   ├── __pycache__
# │   │   │   │   │   ├── author_repository_impl.cpython-313.pyc
# │   │   │   │   │   ├── book_repository_impl.cpython-313.pyc
# │   │   │   │   │   ├── borrowing_repository_impl.cpython-313.pyc
# │   │   │   │   │   ├── database.cpython-313.pyc
# │   │   │   │   │   └── user_repository_impl.cpython-313.pyc
# │   │   │   │   ├── author_repository_impl.py
# │   │   │   │   ├── book_repository_impl.py
# │   │   │   │   ├── borrowing_repository_impl.py
# │   │   │   │   ├── database.py
# │   │   │   │   └── user_repository_impl.py
# │   │   │   └── web
# │   │   │       ├── __pycache__
# │   │   │       │   └── auth_provider.cpython-313.pyc
# │   │   │       └── auth_provider.py
# │   │   ├── presentation
# │   │   │   ├── routers
# │   │   │   │   └── v1
# │   │   │   │       ├── __pycache__
# │   │   │   │       │   ├── api.cpython-313.pyc
# │   │   │   │       │   ├── authors.cpython-313.pyc
# │   │   │   │       │   ├── books.cpython-313.pyc
# │   │   │   │       │   ├── borrowings.cpython-313.pyc
# │   │   │   │       │   └── users.cpython-313.pyc
# │   │   │   │       ├── api.py
# │   │   │   │       ├── authors.py
# │   │   │   │       ├── books.py
# │   │   │   │       ├── borrowings.py
# │   │   │   │       └── users.py
# │   │   │   └── schemas
# │   │   │       ├── __pycache__
# │   │   │       │   ├── author_schema.cpython-313.pyc
# │   │   │       │   ├── book_schema.cpython-313.pyc
# │   │   │       │   ├── borrowing_schema.cpython-313.pyc
# │   │   │       │   ├── token_schema.cpython-313.pyc
# │   │   │       │   └── user_schema.cpython-313.pyc
# │   │   │       ├── author_schema.py
# │   │   │       ├── book_schema.py
# │   │   │       ├── borrowing_schema.py
# │   │   │       ├── token_schema.py
# │   │   │       └── user_schema.py
# │   │   └── main.py
# │   └── test
# ├── checklists
# │   ├── api-checklist.md
# │   └── README.md
# ├── chroma_db
# │   └── chroma.sqlite3
# ├── data
# │   └── library.db
# ├── frontend
# │   ├── assets
# │   │   └── images
# │   │       └── icons
# │   │           ├── app_logo.png
# │   │           └── app_logo2.png
# │   ├── css
# │   │   ├── forms.css
# │   │   └── styles.css
# │   ├── js
# │   │   ├── api.js
# │   │   ├── authors.js
# │   │   ├── books.js
# │   │   └── utils.js
# │   ├── authors.html
# │   ├── books.html
# │   └── index.html
# ├── logs
# │   ├── app.log
# │   ├── exc_err.log
# │   └── val_err.log
# ├── 1.10.1
# ├── DIR_READER.ipynb
# ├── library.db
# ├── pyproject.toml
# └── uv.lock
