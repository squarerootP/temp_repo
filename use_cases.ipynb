# %%
library_use_cases = [
    # --- Library Entity: Book Operations ---
    {
        "Entity": "Book",
        "Operation": "Create",
        "Actor": "Librarian (Admin)",
        "UseCase": "Create Book",
        "Requirements": ["Requires login", "Requires admin role"],
        "Function/Role": ["has_role('admin')"],
    },
    {
        "Entity": "Book",
        "Operation": "Update",
        "Actor": "Librarian (Admin)",
        "UseCase": "Update Book",
        "Requirements": ["Requires login", "Requires admin role"],
        "Function/Role": ["has_role('admin')"],
    },
    {
        "Entity": "Book",
        "Operation": "Delete",
        "Actor": "Librarian (Admin)",
        "UseCase": "Delete Book",
        "Requirements": ["Requires login", "Requires admin role"],
        "Function/Role": ["has_role('admin')"],
    },
    {
        "Entity": "Book",
        "Operation": "Get by ID",
        "Actor": "Any User",
        "UseCase": "Get Book by ID",
        "Requirements": ["No login required"],
        "Function/Role": [],
    },
    {
        "Entity": "Book",
        "Operation": "Search",
        "Actor": "Any User",
        "UseCase": "Search Books",
        "Requirements": ["No login required"],
        "Function/Role": [],
    },
    {
        "Entity": "Book",
        "Operation": "List",
        "Actor": "Any User",
        "UseCase": "List All Books",
        "Requirements": ["No login required"],
        "Function/Role": [],
    },
    # --- Author Operations ---
    {
        "Entity": "Author",
        "Operation": "Create",
        "Actor": "Librarian (Admin)",
        "UseCase": "Create Author",
        "Requirements": ["Requires login", "Requires admin role"],
        "Function/Role": ["has_role('admin')"],
    },
    {
        "Entity": "Author",
        "Operation": "Update",
        "Actor": "Librarian (Admin)",
        "UseCase": "Update Author",
        "Requirements": ["Requires login", "Requires admin role"],
        "Function/Role": ["has_role('admin')"],
    },
    {
        "Entity": "Author",
        "Operation": "Delete",
        "Actor": "Librarian (Admin)",
        "UseCase": "Delete Author",
        "Requirements": ["Requires login", "Requires admin role"],
        "Function/Role": ["has_role('admin')"],
    },
    {
        "Entity": "Author",
        "Operation": "Get by ID",
        "Actor": "Any User",
        "UseCase": "Get Author by ID",
        "Requirements": ["No login required"],
        "Function/Role": [],
    },
    {
        "Entity": "Author",
        "Operation": "Search",
        "Actor": "Any User",
        "UseCase": "Search Authors",
        "Requirements": ["No login required"],
        "Function/Role": [],
    },
    {
        "Entity": "Author",
        "Operation": "List",
        "Actor": "Any User",
        "UseCase": "List All Authors",
        "Requirements": ["No login required"],
        "Function/Role": [],
    },
    # --- User Operations ---
    {
        "Entity": "User",
        "Operation": "Create",
        "Actor": "Administrator",
        "UseCase": "Create User",
        "Requirements": ["Requires login", "Requires admin role"],
        "Function/Role": ["has_role('admin')"],
    },
    {
        "Entity": "User",
        "Operation": "Delete",
        "Actor": "Administrator",
        "UseCase": "Delete User",
        "Requirements": ["Requires login", "Requires admin role"],
        "Function/Role": ["has_role('admin')"],
    },
    {
        "Entity": "User",
        "Operation": "List",
        "Actor": "Administrator",
        "UseCase": "List All Users",
        "Requirements": ["Requires login", "Requires admin role"],
        "Function/Role": ["has_role('admin')"],
    },
    {
        "Entity": "User",
        "Operation": "Get Own Profile",
        "Actor": "Authenticated User",
        "UseCase": "Get Own Profile",
        "Requirements": ["Requires login"],
        "Function/Role": ["get_current_active_user"],
    },
    {
        "Entity": "User",
        "Operation": "Update Own Profile",
        "Actor": "Authenticated User",
        "UseCase": "Update Own Profile",
        "Requirements": ["Requires login"],
        "Function/Role": ["get_current_active_user"],
    },
    # --- Borrowing Operations ---
    {
        "Entity": "Borrowing",
        "Operation": "Create Record",
        "Actor": "Librarian (Admin)",
        "UseCase": "Create Borrowing Record",
        "Requirements": ["Requires login", "Requires admin role"],
        "Function/Role": ["has_role('admin')"],
    },
    {
        "Entity": "Borrowing",
        "Operation": "Update Status",
        "Actor": "Librarian (Admin)",
        "UseCase": "Update Borrowing Status",
        "Requirements": ["Requires login", "Requires admin role"],
        "Function/Role": ["has_role('admin')"],
    },
    {
        "Entity": "Borrowing",
        "Operation": "Delete Record",
        "Actor": "Librarian (Admin)",
        "UseCase": "Delete Borrowing Record",
        "Requirements": ["Requires login", "Requires admin role"],
        "Function/Role": ["has_role('admin')"],
    },
    {
        "Entity": "Borrowing",
        "Operation": "View Records",
        "Actor": "Any User",
        "UseCase": "View Borrowing Records",
        "Requirements": ["No login required"],
        "Function/Role": [],
    },
    {
        "Entity": "Borrowing",
        "Operation": "Search Records",
        "Actor": "Any User",
        "UseCase": "Search Borrowing Records",
        "Requirements": ["No login required"],
        "Function/Role": [],
    },
    # --- RAG (Retrieval-Augmented Generation) ---
    {
        "Entity": "Document",
        "Operation": "Upload",
        "Actor": "Administrator",
        "UseCase": "Upload Document",
        "Requirements": ["Requires login", "Requires admin role"],
        "Function/Role": ["has_role('admin')"],
    },
    {
        "Entity": "Document",
        "Operation": "List All",
        "Actor": "Administrator",
        "UseCase": "List All Processed Documents",
        "Requirements": ["Requires login", "Requires admin role"],
        "Function/Role": ["has_role('admin')"],
    },
    {
        "Entity": "Chat",
        "Operation": "Start Session",
        "Actor": "Authenticated User",
        "UseCase": "Start Chat Session",
        "Requirements": ["Requires login"],
        "Function/Role": ["get_current_user"],
    },
    {
        "Entity": "Chat",
        "Operation": "Send Message",
        "Actor": "Authenticated User",
        "UseCase": "Send Chat Message",
        "Requirements": ["Requires login"],
        "Function/Role": ["get_current_user"],
    },
    {
        "Entity": "Chat",
        "Operation": "View History",
        "Actor": "Authenticated User",
        "UseCase": "View Chat History",
        "Requirements": ["Requires login"],
        "Function/Role": ["get_current_user"],
    },
    {
        "Entity": "Chat",
        "Operation": "List Sessions",
        "Actor": "Authenticated User",
        "UseCase": "List User's Chat Sessions",
        "Requirements": ["Requires login"],
        "Function/Role": ["get_current_user"],
    },
    # --- Authentication ---
    {
        "Entity": "Authentication",
        "Operation": "Login",
        "Actor": "Any User",
        "UseCase": "Login (Get Access Token)",
        "Requirements": ["No login required"],
        "Function/Role": ["username/password form"],
    },
]

# Example of loading into pandas
# import pandas as pd
# df = pd.DataFrame(library_use_cases)
# display(df)

# %%
import pandas as pd

df = pd.DataFrame(library_use_cases)

# %%
df.to_excel("library_use_cases.xlsx", index=False)
